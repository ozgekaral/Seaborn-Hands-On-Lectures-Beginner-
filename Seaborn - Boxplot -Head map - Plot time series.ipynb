# %% [markdown]
# ### Boxplot ###

# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.boxplot(x=df['total_bill']);

# %% [markdown]
# #### Crossover for Boxplot ####

# %%
sns.boxplot(x='day', y='total_bill', data=df);

# %%
sns.boxplot(x='time', y='total_bill', data=df);

# %%
sns.boxplot(x='size', y='total_bill', data=df);

# %%
sns.boxplot(x='day', y='total_bill', hue='sex', data=df);

# %%
sns.catplot(y='total_bill', kind='violin', data=df);

# %%
sns.catplot(x='day',y='total_bill', kind='violin', data=df);

# %%
sns.catplot(x='day',y='total_bill', hue='sex', kind='violin', data=df);

# %% [markdown]
# ### Scatterplot-Correlation ###

# %% [markdown]
# We use scatterplot for integer correlations.

# %%
sns.scatterplot(x='total_bill', y='tip', data=df);

# %%
sns.scatterplot(x='total_bill', y='tip', hue='time', data=df);

# %%
sns.scatterplot(x='total_bill', y='tip', hue='time', style='time', data=df);

# %%
sns.scatterplot(x='total_bill', y='tip', hue='time', style='day', data=df);

# %%
sns.scatterplot(x='total_bill', y='tip', size='size', data=df);

# %%
sns.scatterplot(x='total_bill', y='tip', hue='size', size='size', data=df);

# %% [markdown]
# Showing linear correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lmplot(x='total_bill', y='tip', data=df);

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=df);

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', data=df);

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', row='sex', data=df);

# %%
import seaborn as sns

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df_i=sns.load_dataset('iris')
df_i.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_i.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df_i.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df_i.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df_i.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df_i.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df_i.shape
# Out:
# (150, 5)

# %%
df_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_i['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.barplot(x=df_i['species'], y=df_i.species.index, data=df_i);

# %%
sns.pairplot(df_i);

# %%
sns.pairplot(df_i, hue='species');

# %%
sns.pairplot(df_i, hue='species', markers=['o','s','D']);

# %% [markdown]
# #### Adding a line ####

# %%
sns.pairplot(df_i, kind='reg');

# %%
sns.pairplot(df_i, hue='species', kind='reg');

# %% [markdown]
# ### Head Map ###

# %%
import seaborn as sns

# %%
sns.load_dataset('flights')
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df_f=sns.load_dataset('flights')

# %%
df_f.info
# Out:
# <bound method DataFrame.info of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
df_f.shape
# Out:
# (144, 3)

# %%
df_f.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
df_f.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
df_f.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
df_f.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
df_f['month'].value_counts()
# Out:
# Dec    12
# Nov    12
# Oct    12
# Sep    12
# Aug    12
# Jul    12
# Jun    12
# May    12
# Apr    12
# Mar    12
# Feb    12
# Jan    12
# Name: month, dtype: int64

# %% [markdown]
# To use 'heatmap',firstly you should use '.pivot' in pandas.

# %%
df_f=df_f.pivot('month', 'year', 'passengers')

# %%
df_f
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df_f);

# %%
df_f
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(df_f, annot=True, fmt='d', linewidths=.5,);

# %%
sns.heatmap(df_f, annot=True, fmt='d', linewidths=.5, cbar=False);

# %% [markdown]
# ### Line Chart ###

# %%
import seaborn as sns

# %%
sns.load_dataset('fmri')
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
df_m=sns.load_dataset('fmri')
df_m
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
df_m.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df_m.tail()
# Out:
#      subject  timepoint event    region    signal
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
df_m.shape
# Out:
# (1064, 5)

# %%
df_m.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
df_m.isnull().sum()
# Out:
# subject      0
# timepoint    0
# event        0
# region       0
# signal       0
# dtype: int64

# %%
df_m.describe().T
# Out:
#             count     mean       std       min      25%       50%        75%  \
# timepoint  1064.0  9.00000  5.479801  0.000000  4.00000  9.000000  14.000000
# signal     1064.0  0.00354  0.093930 -0.255486 -0.04607 -0.013653   0.024293
#
#                  max
# timepoint  18.000000
# signal      0.564985

# %%
df_m['subject'].value_counts()
# Out:
# s9     76
# s2     76
# s1     76
# s7     76
# s12    76
# s0     76
# s10    76
# s6     76
# s13    76
# s3     76
# s4     76
# s11    76
# s8     76
# s5     76
# Name: subject, dtype: int64

# %%
df_m['event'].value_counts()
# Out:
# stim    532
# cue     532
# Name: event, dtype: int64

# %%
df_m['region'].value_counts()
# Out:
# parietal    532
# frontal     532
# Name: region, dtype: int64

# %%
df_m.groupby('timepoint')['signal'].count()
# Out:
# timepoint
# 0     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 8     56
# 9     56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 17    56
# 18    56
# Name: signal, dtype: int64

# %% [markdown]
# We expect that all values are unique.

# %%
df_m.groupby('signal')['timepoint'].count()
# Out:
# signal
# -0.255486    1
# -0.238474    1
# -0.224351    1
# -0.181241    1
# -0.178510    1
#             ..
#  0.455575    1
#  0.460896    1
#  0.476055    1
#  0.494787    1
#  0.564985    1
# Name: timepoint, Length: 1064, dtype: int64

# %%
df_m.groupby('signal').count()
# Out:
#            subject  timepoint  event  region
# signal
# -0.255486        1          1      1       1
# -0.238474        1          1      1       1
# -0.224351        1          1      1       1
# -0.181241        1          1      1       1
# -0.178510        1          1      1       1
# ...            ...        ...    ...     ...
#  0.455575        1          1      1       1
#  0.460896        1          1      1       1
#  0.476055        1          1      1       1
#  0.494787        1          1      1       1
#  0.564985        1          1      1       1
#
# [1064 rows x 4 columns]

# %%
df_m.groupby('timepoint')['signal'].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# timepoint
# 0           56.0 -0.016662  0.028326 -0.064454 -0.039169 -0.018382  0.003539
# 1           56.0 -0.025002  0.030641 -0.082174 -0.046299 -0.024533 -0.005388
# 2           56.0 -0.012873  0.035440 -0.110565 -0.034944 -0.013183  0.009318
# 3           56.0  0.034446  0.058260 -0.089708 -0.001157  0.028430  0.061840
# 4           56.0  0.098194  0.092838 -0.046347  0.030912  0.070166  0.144911
# 5           56.0  0.137725  0.123353 -0.017946  0.042762  0.096535  0.211638
# 6           56.0  0.127515  0.137332 -0.054405  0.022409  0.068850  0.218919
# 7           56.0  0.075660  0.129704 -0.108222 -0.016252  0.032486  0.144781
# 8           56.0  0.013420  0.104216 -0.181241 -0.049453 -0.012834  0.030396
# 9           56.0 -0.032041  0.072728 -0.152929 -0.075693 -0.038496  0.008717
# 10          56.0 -0.053685  0.053148 -0.176453 -0.078893 -0.052906 -0.015302
# ...

# %%
sns.lineplot(x='timepoint', y='signal', data=df_m);

# %%
sns.lineplot(x='timepoint', y='signal', hue='event', data=df_m);

# %%
sns.lineplot(x='timepoint', y='signal', hue='event', style='event', markers=True, dashes=False,  data=df_m);

# %%
sns.lineplot(x='timepoint', y='signal', hue='region', style='event', markers=True, dashes=False,  data=df_m);

# %% [markdown]
# ### How to plot a time series graph using seaborn ###

# %%
# !pip install pandas_datareader
import pandas_datareader as pr

# %%
df_a=pr.get_data_yahoo('AAPL', start='2012-01-01', end='2019-01-01')
df_a
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.540046
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.607436
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.747405
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.880664
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.860232
# ...               ...        ...        ...        ...          ...        ...
# 2018-12-24  37.887501  36.647499  37.037498  36.707500  148676800.0  35.487961
# 2018-12-26  39.307499  36.680000  37.075001  39.292500  234330000.0  37.987083
# 2018-12-27  39.192501  37.517502  38.959999  39.037498  212468400.0  37.740543
# 2018-12-28  39.630001  38.637501  39.375000  39.057499  169165600.0  37.759884
# 2018-12-31  39.840000  39.119999  39.632500  39.435001  140014000.0  38.124844
#
# ...

# %%
df_a.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.540046
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.607436
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.747405
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.880664
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.860232

# %%
df_a.tail()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2018-12-24  37.887501  36.647499  37.037498  36.707500  148676800.0  35.487961
# 2018-12-26  39.307499  36.680000  37.075001  39.292500  234330000.0  37.987083
# 2018-12-27  39.192501  37.517502  38.959999  39.037498  212468400.0  37.740543
# 2018-12-28  39.630001  38.637501  39.375000  39.057499  169165600.0  37.759884
# 2018-12-31  39.840000  39.119999  39.632500  39.435001  140014000.0  38.124844

# %%
df_a.isnull().sum()
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df_a.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
df_a.describe().T
# Out:
#             count          mean           std           min           25%  \
# High       1760.0  2.904508e+01  1.033915e+01  1.427143e+01  2.065893e+01
# Low        1760.0  2.852997e+01  1.016784e+01  1.375357e+01  2.035313e+01
# Open       1760.0  2.879484e+01  1.025351e+01  1.385607e+01  2.051804e+01
# Close      1760.0  2.879116e+01  1.025546e+01  1.394750e+01  2.045723e+01
# Volume     1760.0  2.559302e+08  1.930336e+08  4.590360e+07  1.231063e+08
# Adj Close  1760.0  2.649923e+01  1.040184e+01  1.208460e+01  1.769552e+01
#
#                     50%           75%           max
# High       2.722125e+01  3.561375e+01  5.836750e+01
# Low        2.670500e+01  3.522625e+01  5.744500e+01
# Open       2.697250e+01  3.541750e+01  5.769500e+01
# Close      2.698500e+01  3.541813e+01  5.801750e+01
# Volume     1.939804e+08  3.240833e+08  1.506120e+09
# Adj Close  2.472085e+01  3.334499e+01  5.589495e+01

# %%
df_a['Volume']
# Out:
# Date
# 2012-01-03    302220800.0
# 2012-01-04    260022000.0
# 2012-01-05    271269600.0
# 2012-01-06    318292800.0
# 2012-01-09    394024400.0
#                  ...
# 2018-12-24    148676800.0
# 2018-12-26    234330000.0
# 2018-12-27    212468400.0
# 2018-12-28    169165600.0
# 2018-12-31    140014000.0
# Name: Volume, Length: 1760, dtype: float64

# %%
df_a['Volume'].plot();

# %%
df_a['Volume'].index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1760, freq=None)

# %%
import pandas as pd

# %%
df_a_o=df_a['Volume']

# %%
df_a_o.index=pd.DatetimeIndex(df_a_o.index)

# %%
df_a_o
# Out:
# Date
# 2012-01-03    302220800.0
# 2012-01-04    260022000.0
# 2012-01-05    271269600.0
# 2012-01-06    318292800.0
# 2012-01-09    394024400.0
#                  ...
# 2018-12-24    148676800.0
# 2018-12-26    234330000.0
# 2018-12-27    212468400.0
# 2018-12-28    169165600.0
# 2018-12-31    140014000.0
# Name: Volume, Length: 1760, dtype: float64

# %%
df_a_o.plot();

# %% [markdown]
# ### Summary ###

# %% [markdown]
# #### Numerical Data Plotting ####
# * relplot()
# * scatterplot()
# * lineplot()
# #### Categorical Data Ploting ####
# * catplot()
# * boxplot()
# * stripplot()
# * swarmplot()
# #### Visualizing Distribution of the Data ####
# * distplot()
# * kdeplot()
# * jointplot()
# * rugplot()
# #### Linear Regression and Relationship ####
# * regplot()
# * lmplot()

# %% [markdown]
# -----------------------------
